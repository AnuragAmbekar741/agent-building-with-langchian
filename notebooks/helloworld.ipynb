# %%
pip install langgraph typing-extensions
# Out:
# Collecting langgraph
#   Downloading langgraph-1.0.5-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.12/site-packages (4.11.0)
# Collecting langchain-core>=0.1 (from langgraph)
#   Downloading langchain_core-1.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph)
#   Downloading langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph)
#   Downloading langgraph_sdk-0.3.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting pydantic>=2.7.4 (from langgraph)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Collecting xxhash>=3.5.0 (from langgraph)
#   Downloading xxhash-3.6.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core>=0.1->langgraph)
#   Downloading langsmith-0.5.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (8.2.2)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core>=0.1->langgraph)
#   Downloading uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.1 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.12.1-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph)
#   Downloading orjson-3.11.5-cp312-cp312-macosx_15_0_arm64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.6.0)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.7.4->langgraph)
#   Downloading pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-extensions
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.7.4->langgraph)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.10.5)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.7)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (2.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.2)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.2.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.3.0)
# Downloading langgraph-1.0.5-py3-none-any.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.1/157.1 kB 3.6 MB/s eta 0:00:0000:01
# Downloading langchain_core-1.2.3-py3-none-any.whl (476 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 476.4/476.4 kB 10.2 MB/s eta 0:00:00a 0:00:01
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 3.7 MB/s eta 0:00:00
# Downloading langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.1-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.9 MB/s eta 0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 22.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 25.0 MB/s eta 0:00:0000:0100:01
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.2 MB/s eta 0:00:00
# Downloading xxhash-3.6.0-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading langsmith-0.5.0-py3-none-any.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.7/273.7 kB 8.7 MB/s eta 0:00:00
# Downloading orjson-3.11.5-cp312-cp312-macosx_15_0_arm64.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 13.5 MB/s eta 0:00:00
# Downloading ormsgpack-1.12.1-cp312-cp312-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (376 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.7/376.7 kB 30.7 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (603 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.2/603.2 kB 22.2 MB/s eta 0:00:00
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: xxhash, uuid-utils, typing-extensions, ormsgpack, orjson, h11, typing-inspection, pydantic-core, httpcore, pydantic, httpx, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.6
#     Uninstalling pydantic_core-2.14.6:
#       Successfully uninstalled pydantic_core-2.14.6
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
# Successfully installed h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 langchain-core-1.2.3 langgraph-1.0.5 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.3.1 langsmith-0.5.0 orjson-3.11.5 ormsgpack-1.12.1 pydantic-2.12.5 pydantic-core-2.41.5 typing-extensions-4.15.0 typing-inspection-0.4.2 uuid-utils-0.12.0 xxhash-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from typing import TypedDict
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
  message : str

def greeting_node(state:AgentState) -> AgentState:
  """ Simple node that adds greeting message to the state"""

  state['message'] = 'Hello ' + state['message'] + " how is your day going?"

  return state

# %%
graph = StateGraph(AgentState)

graph.add_node("greeter",greeting_node)

graph.set_entry_point("greeter")

graph.set_finish_point("greeter")

app = graph.compile()

# %%
from IPython.display import Image, display
display(Image(app.get_graph().draw_mermaid_png()))

# %%
result = app.invoke({"message":"Bob"})

result["message"]
# Out:
# 'Hello Bob how is your day going?'
